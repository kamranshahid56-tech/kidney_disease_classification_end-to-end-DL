# %%
d = {"key":"value", "key1":"value1"}

# %%
d['key']
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"value", "key1":"value1"})

# %%
d2.key
# Out:
# 'value'

# %%
from ensure import ensure_annotations

# %%
def product(x: int, y: int) -> int:
    return x * y

# %%
product(x = 2, y = "8")
# Out:
# '88'

# %%
@ensure_annotations
def products(x: int, y: int) -> int:
    return x * y

# %%
products(x = 2, y = 8)
# Out:
# 16
